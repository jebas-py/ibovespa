# %% [markdown]
# # Libraries and versions

# %%
python_version = !python -V #version 3.8.8
import pandas as pd #version 1.2.4
import numpy as np #version 1.20.1
import seaborn as sns #version 0.11.1
import matplotlib as plt #version 3.3.4

#Modelo
from sklearn.metrics import mean_squared_log_error, r2_score
from sklearn.linear_model import Ridge
from sklearn.model_selection import TimeSeriesSplit

# %%
print(f'Python version - {python_version[0][7:]}')
print(f'Pandas version - {pd.__version__}')
print(f'Numpy version - {np.__version__}')
print(f'Seaborn version - {sns.__version__}')
print(f'Matplotlib version - {plt.__version__}')
# Out:
# Python version - 3.8.8
# Pandas version - 1.2.4
# Numpy version - 1.20.1
# Seaborn version - 0.11.1
# Matplotlib version - 3.3.4

# %% [markdown]
# # Configurations

# %% [markdown]
# ## Pandas

# %%
#apresentará 500 colunas e linhas
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 20)

# %% [markdown]
# ## Seaborn

# %%
sns.set_palette('inferno')
sns.set_style('darkgrid')

def configuration(graphic_object, title=None, xlabel=None, ylabel=None, colors=None):
    graphic_object.figure.set_size_inches(20,8)
    graphic_object.set_title(title, color=colors, fontsize=16)
    graphic_object.set_xlabel(xlabel, color=colors, fontsize=14)
    graphic_object.set_ylabel(ylabel, color=colors, fontsize=14)
    graphic_object = graphic_object

# %% [markdown]
# ## Warnings

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Base

# %%
bvsp = pd.read_csv('bvsp_modelado_original.csv')
bvsp.head()
# Out:
#          data     abertura         alta        baixa   fechamento  \
# 0  1995-02-27  3217.399902  3345.800049  3184.399902  3270.899902
# 1  1995-02-28  3217.399902  3345.800049  3184.399902  3270.899902
# 2  1995-03-01  3217.399902  3345.800049  3184.399902  3270.899902
# 3  1995-03-02  3270.899902  3270.899902  2970.199951  2989.100098
# 4  1995-03-03  2989.100098  3018.100098  2841.699951  2988.000000
#
#    var_abertura  media_movel_180  media_movel_240  media_movel_360  \
# 0      0.000000      4404.944448      3785.654587      2719.633892
# 1      0.000000      4404.830560      3792.938337      2728.090837
# 2      0.000000      4404.943892      3800.340836      2736.526114
# 3     53.500000      4405.345558      3807.966252      2745.099169
# 4   -281.799804      4404.507225      3814.417502      2752.882781
#
#    media_movel_480
# 0      2057.587711
# 1      2064.238961
# 2      2070.890836
# 3      2077.654585
# 4      2083.832502

# %% [markdown]
# ### Informações

# %%
bvsp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6637 entries, 0 to 6636
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   data             6637 non-null   object
#  1   abertura         6637 non-null   float64
#  2   alta             6637 non-null   float64
#  3   baixa            6637 non-null   float64
#  4   fechamento       6637 non-null   float64
#  5   var_abertura     6637 non-null   float64
#  6   media_movel_180  6637 non-null   float64
#  7   media_movel_240  6637 non-null   float64
#  8   media_movel_360  6637 non-null   float64
#  9   media_movel_480  6637 non-null   float64
# dtypes: float64(9), object(1)
# memory usage: 518.6+ KB

# %% [markdown]
# ### Transformar índice em data

# %%
#transforma coluna em data
bvsp['data'] = pd.to_datetime(bvsp['data'])

#transforma o índice em data
bvsp.set_index('data', inplace=True)

# %% [markdown]
# ### Separar dados de treino e validação

# %%
dt_treino = bvsp.loc[:'2020-05-29']
dt_validacao = bvsp.loc['2020-06-01':]

# %% [markdown]
# ### Fechamento

# %%
X = bvsp.drop(columns=['alta', 'baixa', 'fechamento'])
y_fechamento = bvsp['fechamento']

divisoes = 25
tscv = TimeSeriesSplit(n_splits=divisoes)
contador = 0
lista_erro = []
lista_iteracao = []
lista_r2 = []
for treino_indice, teste_indice in tscv.split(X):
    X_treino, X_teste = X.iloc[treino_indice], X.iloc[teste_indice]
    y_treino_fechamento, y_teste_fechamento = y_fechamento[treino_indice], y_fechamento[teste_indice]
    
    #modelo
    mdl_fechamento = Ridge()
    mdl_fechamento.fit(X_treino, y_treino_fechamento)
    y_fechamento_previsto = mdl_fechamento.predict(X_teste)
    
    #precisão
    erro = mean_squared_log_error(y_teste_fechamento, y_fechamento_previsto)
    r2 = r2_score(y_teste_fechamento, y_fechamento_previsto)
    
    #incrementa lista e contador
    lista_erro.append(erro)
    lista_iteracao.append(contador)
    lista_r2.append(r2)
    contador += 1
        
    print(f'{contador}° iteração')
    print(f'Perído Treino - {X_treino.index[0]} / {X_treino.index[-1]}')
    print(f'Amostra Treino - {X_treino.shape[0]}')
    print(f'Período Teste - {y_teste_fechamento.index[0]} / {y_teste_fechamento.index[-1]}')
    print(f'Amostra Teste - {len(y_teste_fechamento)}')
    print(f'Erro Médio Quadrático = {erro:.5f}\nR2 = {r2:.5f}')
    print('='*90)

fig, axes = plt.pyplot.subplots(1,2, figsize=(20,6))    
sns.lineplot(x=lista_iteracao, y=lista_erro, ax=axes[0], label='Erro Médio Quadrático')
sns.lineplot(x=lista_iteracao, y=lista_r2, ax=axes[1], label='R2')
# Out:
# 1° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1996-02-27 00:00:00
# Amostra Treino - 262
# Período Teste - 1996-02-28 00:00:00 / 1997-02-18 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00728
# R2 = 0.60422
# ==========================================================================================
# 2° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1997-02-18 00:00:00
# Amostra Treino - 517
# Período Teste - 1997-02-19 00:00:00 / 1998-02-10 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00112
# R2 = 0.93578
# ==========================================================================================
# 3° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1998-02-10 00:00:00
# Amostra Treino - 772
# Período Teste - 1998-02-11 00:00:00 / 1999-02-02 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00200
# R2 = 0.97260
# ==========================================================================================
# 4° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1999-02-02 00:00:00
# Amostra Treino - 1027
# Período Teste - 1999-02-03 00:00:00 / 2000-01-25 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00048
# R2 = 0.98399
# ==========================================================================================
# 5° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2000-01-25 00:00:00
# Amostra Treino - 1282
# Período Teste - 2000-01-26 00:00:00 / 2001-01-16 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00043
# R2 = 0.93754
# ==========================================================================================
# 6° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2001-01-16 00:00:00
# Amostra Treino - 1537
# Período Teste - 2001-01-17 00:00:00 / 2002-01-08 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00041
# R2 = 0.97784
# ==========================================================================================
# 7° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2002-01-08 00:00:00
# Amostra Treino - 1792
# Período Teste - 2002-01-09 00:00:00 / 2002-12-31 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00043
# R2 = 0.98154
# ==========================================================================================
# 8° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2002-12-31 00:00:00
# Amostra Treino - 2047
# Período Teste - 2003-01-01 00:00:00 / 2003-12-23 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00026
# R2 = 0.99471
# ==========================================================================================
# 9° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2003-12-23 00:00:00
# Amostra Treino - 2302
# Período Teste - 2003-12-24 00:00:00 / 2004-12-14 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00032
# R2 = 0.94030
# ==========================================================================================
# 10° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2004-12-14 00:00:00
# Amostra Treino - 2557
# Período Teste - 2004-12-15 00:00:00 / 2005-12-20 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00024
# R2 = 0.97401
# ==========================================================================================
# 11° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2005-12-20 00:00:00
# Amostra Treino - 2812
# Período Teste - 2005-12-21 00:00:00 / 2006-12-13 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00023
# R2 = 0.93980
# ==========================================================================================
# 12° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2006-12-13 00:00:00
# Amostra Treino - 3067
# Período Teste - 2006-12-14 00:00:00 / 2007-12-28 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00029
# R2 = 0.98343
# ==========================================================================================
# 13° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2007-12-28 00:00:00
# Amostra Treino - 3322
# Período Teste - 2008-01-02 00:00:00 / 2009-01-09 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00113
# R2 = 0.98257
# ==========================================================================================
# 14° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2009-01-09 00:00:00
# Amostra Treino - 3577
# Período Teste - 2009-01-12 00:00:00 / 2010-01-20 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00035
# R2 = 0.99168
# ==========================================================================================
# 15° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2010-01-20 00:00:00
# Amostra Treino - 3832
# Período Teste - 2010-01-21 00:00:00 / 2011-02-01 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00016
# R2 = 0.92271
# ==========================================================================================
# 16° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2011-02-01 00:00:00
# Amostra Treino - 4087
# Período Teste - 2011-02-02 00:00:00 / 2012-02-08 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00024
# R2 = 0.96789
# ==========================================================================================
# 17° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2012-02-08 00:00:00
# Amostra Treino - 4342
# Período Teste - 2012-02-09 00:00:00 / 2013-02-26 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00018
# R2 = 0.95646
# ==========================================================================================
# 18° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2013-02-26 00:00:00
# Amostra Treino - 4597
# Período Teste - 2013-02-27 00:00:00 / 2014-03-06 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00017
# R2 = 0.95981
# ==========================================================================================
# 19° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2014-03-06 00:00:00
# Amostra Treino - 4852
# Período Teste - 2014-03-07 00:00:00 / 2015-03-17 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00026
# R2 = 0.94618
# ==========================================================================================
# 20° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2015-03-17 00:00:00
# Amostra Treino - 5107
# Período Teste - 2015-03-18 00:00:00 / 2016-03-31 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00027
# R2 = 0.97481
# ==========================================================================================
# 21° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2016-03-31 00:00:00
# Amostra Treino - 5362
# Período Teste - 2016-04-01 00:00:00 / 2017-04-06 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00020
# R2 = 0.97801
# ==========================================================================================
# 22° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2017-04-06 00:00:00
# Amostra Treino - 5617
# Período Teste - 2017-04-07 00:00:00 / 2018-04-09 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00015
# R2 = 0.98743
# ==========================================================================================
# 23° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2018-04-09 00:00:00
# Amostra Treino - 5872
# Período Teste - 2018-04-10 00:00:00 / 2019-04-23 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00020
# R2 = 0.97781
# ==========================================================================================
# 24° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2019-04-23 00:00:00
# Amostra Treino - 6127
# Período Teste - 2019-04-24 00:00:00 / 2020-05-04 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00068
# R2 = 0.96880
# ==========================================================================================
# 25° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2020-05-04 00:00:00
# Amostra Treino - 6382
# Período Teste - 2020-05-05 00:00:00 / 2021-05-14 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00021
# R2 = 0.98313
# ==========================================================================================
# <AxesSubplot:>

# %% [markdown]
# ### Baixa

# %%
X = bvsp.drop(columns=['alta', 'baixa', 'fechamento'])
y_baixa = bvsp['baixa']

divisoes = 25
tscv = TimeSeriesSplit(n_splits=divisoes)
contador = 0
lista_erro = []
lista_iteracao = []
lista_r2 = []
for treino_indice, teste_indice in tscv.split(X):
    X_treino, X_teste = X.iloc[treino_indice], X.iloc[teste_indice]
    y_treino_baixa, y_teste_baixa = y_baixa[treino_indice], y_baixa[teste_indice]
    
    #modelo
    mdl_baixa = Ridge()
    mdl_baixa.fit(X_treino, y_treino_baixa)
    y_baixa_previsto = mdl_baixa.predict(X_teste)
    
    #precisão
    erro = mean_squared_log_error(y_teste_baixa, y_baixa_previsto)
    r2 = r2_score(y_teste_baixa, y_baixa_previsto)
    
    #incrementa lista e contador
    lista_erro.append(erro)
    lista_iteracao.append(contador)
    lista_r2.append(r2)
    contador += 1
        
    print(f'{contador}° iteração')
    print(f'Perído Treino - {X_treino.index[0]} / {X_treino.index[-1]}')
    print(f'Amostra Treino - {X_treino.shape[0]}')
    print(f'Período Teste - {y_teste_baixa.index[0]} / {y_teste_baixa.index[-1]}')
    print(f'Amostra Teste - {len(y_teste_baixa)}')
    print(f'Erro Médio Quadrático = {erro:.5f}\nR2 = {r2:.5f}')
    print('='*90)

fig, axes = plt.pyplot.subplots(1,2, figsize=(20,6))    
sns.lineplot(x=lista_iteracao, y=lista_erro, ax=axes[0], label='Erro Médio Quadrático')
sns.lineplot(x=lista_iteracao, y=lista_r2, ax=axes[1], label='R2')
# Out:
# 1° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1996-02-27 00:00:00
# Amostra Treino - 262
# Período Teste - 1996-02-28 00:00:00 / 1997-02-18 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00028
# R2 = 0.98485
# ==========================================================================================
# 2° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1997-02-18 00:00:00
# Amostra Treino - 517
# Período Teste - 1997-02-19 00:00:00 / 1998-02-10 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00079
# R2 = 0.95321
# ==========================================================================================
# 3° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1998-02-10 00:00:00
# Amostra Treino - 772
# Período Teste - 1998-02-11 00:00:00 / 1999-02-02 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00186
# R2 = 0.97733
# ==========================================================================================
# 4° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1999-02-02 00:00:00
# Amostra Treino - 1027
# Período Teste - 1999-02-03 00:00:00 / 2000-01-25 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00031
# R2 = 0.98981
# ==========================================================================================
# 5° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2000-01-25 00:00:00
# Amostra Treino - 1282
# Período Teste - 2000-01-26 00:00:00 / 2001-01-16 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00026
# R2 = 0.96484
# ==========================================================================================
# 6° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2001-01-16 00:00:00
# Amostra Treino - 1537
# Período Teste - 2001-01-17 00:00:00 / 2002-01-08 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00018
# R2 = 0.99032
# ==========================================================================================
# 7° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2002-01-08 00:00:00
# Amostra Treino - 1792
# Período Teste - 2002-01-09 00:00:00 / 2002-12-31 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00019
# R2 = 0.99218
# ==========================================================================================
# 8° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2002-12-31 00:00:00
# Amostra Treino - 2047
# Período Teste - 2003-01-01 00:00:00 / 2003-12-23 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00011
# R2 = 0.99784
# ==========================================================================================
# 9° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2003-12-23 00:00:00
# Amostra Treino - 2302
# Período Teste - 2003-12-24 00:00:00 / 2004-12-14 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00016
# R2 = 0.97154
# ==========================================================================================
# 10° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2004-12-14 00:00:00
# Amostra Treino - 2557
# Período Teste - 2004-12-15 00:00:00 / 2005-12-20 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00011
# R2 = 0.98829
# ==========================================================================================
# 11° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2005-12-20 00:00:00
# Amostra Treino - 2812
# Período Teste - 2005-12-21 00:00:00 / 2006-12-13 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00009
# R2 = 0.97682
# ==========================================================================================
# 12° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2006-12-13 00:00:00
# Amostra Treino - 3067
# Período Teste - 2006-12-14 00:00:00 / 2007-12-28 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00018
# R2 = 0.99008
# ==========================================================================================
# 13° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2007-12-28 00:00:00
# Amostra Treino - 3322
# Período Teste - 2008-01-02 00:00:00 / 2009-01-09 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00080
# R2 = 0.98913
# ==========================================================================================
# 14° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2009-01-09 00:00:00
# Amostra Treino - 3577
# Período Teste - 2009-01-12 00:00:00 / 2010-01-20 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00015
# R2 = 0.99622
# ==========================================================================================
# 15° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2010-01-20 00:00:00
# Amostra Treino - 3832
# Período Teste - 2010-01-21 00:00:00 / 2011-02-01 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00012
# R2 = 0.94926
# ==========================================================================================
# 16° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2011-02-01 00:00:00
# Amostra Treino - 4087
# Período Teste - 2011-02-02 00:00:00 / 2012-02-08 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00015
# R2 = 0.98061
# ==========================================================================================
# 17° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2012-02-08 00:00:00
# Amostra Treino - 4342
# Período Teste - 2012-02-09 00:00:00 / 2013-02-26 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00008
# R2 = 0.98239
# ==========================================================================================
# 18° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2013-02-26 00:00:00
# Amostra Treino - 4597
# Período Teste - 2013-02-27 00:00:00 / 2014-03-06 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00008
# R2 = 0.98125
# ==========================================================================================
# 19° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2014-03-06 00:00:00
# Amostra Treino - 4852
# Período Teste - 2014-03-07 00:00:00 / 2015-03-17 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00012
# R2 = 0.97540
# ==========================================================================================
# 20° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2015-03-17 00:00:00
# Amostra Treino - 5107
# Período Teste - 2015-03-18 00:00:00 / 2016-03-31 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00012
# R2 = 0.98958
# ==========================================================================================
# 21° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2016-03-31 00:00:00
# Amostra Treino - 5362
# Período Teste - 2016-04-01 00:00:00 / 2017-04-06 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00010
# R2 = 0.98935
# ==========================================================================================
# 22° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2017-04-06 00:00:00
# Amostra Treino - 5617
# Período Teste - 2017-04-07 00:00:00 / 2018-04-09 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00010
# R2 = 0.99191
# ==========================================================================================
# 23° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2018-04-09 00:00:00
# Amostra Treino - 5872
# Período Teste - 2018-04-10 00:00:00 / 2019-04-23 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00010
# R2 = 0.98975
# ==========================================================================================
# 24° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2019-04-23 00:00:00
# Amostra Treino - 6127
# Período Teste - 2019-04-24 00:00:00 / 2020-05-04 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00060
# R2 = 0.97652
# ==========================================================================================
# 25° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2020-05-04 00:00:00
# Amostra Treino - 6382
# Período Teste - 2020-05-05 00:00:00 / 2021-05-14 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00011
# R2 = 0.99143
# ==========================================================================================
# <AxesSubplot:>

# %% [markdown]
# ### Alta

# %%
X = bvsp.drop(columns=['alta', 'baixa', 'fechamento'])
y_alta = bvsp['alta']

divisoes = 25
tscv = TimeSeriesSplit(n_splits=divisoes)
contador = 0
lista_erro = []
lista_iteracao = []
lista_r2 = []
for treino_indice, teste_indice in tscv.split(X):
    X_treino, X_teste = X.iloc[treino_indice], X.iloc[teste_indice]
    y_treino_alta, y_teste_alta = y_alta[treino_indice], y_alta[teste_indice]
    
    #modelo
    mdl_alta = Ridge()
    mdl_alta.fit(X_treino, y_treino_alta)
    y_alta_previsto = mdl_alta.predict(X_teste)
    
    #precisão
    erro = mean_squared_log_error(y_teste_alta, y_alta_previsto)
    r2 = r2_score(y_teste_alta, y_alta_previsto)
    
    #incrementa lista e contador
    lista_erro.append(erro)
    lista_iteracao.append(contador)
    lista_r2.append(r2)
    contador += 1
        
    print(f'{contador}° iteração')
    print(f'Perído Treino - {X_treino.index[0]} / {X_treino.index[-1]}')
    print(f'Amostra Treino - {X_treino.shape[0]}')
    print(f'Período Teste - {y_teste_alta.index[0]} / {y_teste_alta.index[-1]}')
    print(f'Amostra Teste - {len(y_teste_alta)}')
    print(f'Erro Médio Quadrático = {erro:.5f}\nR2 = {r2:.5f}')
    print('='*90)

fig, axes = plt.pyplot.subplots(1,2, figsize=(20,6))    
sns.lineplot(x=lista_iteracao, y=lista_erro, ax=axes[0], label='Erro Médio Quadrático')
sns.lineplot(x=lista_iteracao, y=lista_r2, ax=axes[1], label='R2')
# Out:
# 1° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1996-02-27 00:00:00
# Amostra Treino - 262
# Período Teste - 1996-02-28 00:00:00 / 1997-02-18 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00509
# R2 = 0.71433
# ==========================================================================================
# 2° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1997-02-18 00:00:00
# Amostra Treino - 517
# Período Teste - 1997-02-19 00:00:00 / 1998-02-10 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00070
# R2 = 0.96396
# ==========================================================================================
# 3° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1998-02-10 00:00:00
# Amostra Treino - 772
# Período Teste - 1998-02-11 00:00:00 / 1999-02-02 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00088
# R2 = 0.98737
# ==========================================================================================
# 4° iteração
# Perído Treino - 1995-02-27 00:00:00 / 1999-02-02 00:00:00
# Amostra Treino - 1027
# Período Teste - 1999-02-03 00:00:00 / 2000-01-25 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00027
# R2 = 0.99037
# ==========================================================================================
# 5° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2000-01-25 00:00:00
# Amostra Treino - 1282
# Período Teste - 2000-01-26 00:00:00 / 2001-01-16 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00017
# R2 = 0.97465
# ==========================================================================================
# 6° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2001-01-16 00:00:00
# Amostra Treino - 1537
# Período Teste - 2001-01-17 00:00:00 / 2002-01-08 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00023
# R2 = 0.98754
# ==========================================================================================
# 7° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2002-01-08 00:00:00
# Amostra Treino - 1792
# Período Teste - 2002-01-09 00:00:00 / 2002-12-31 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00019
# R2 = 0.99181
# ==========================================================================================
# 8° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2002-12-31 00:00:00
# Amostra Treino - 2047
# Período Teste - 2003-01-01 00:00:00 / 2003-12-23 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00009
# R2 = 0.99805
# ==========================================================================================
# 9° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2003-12-23 00:00:00
# Amostra Treino - 2302
# Período Teste - 2003-12-24 00:00:00 / 2004-12-14 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00010
# R2 = 0.98054
# ==========================================================================================
# 10° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2004-12-14 00:00:00
# Amostra Treino - 2557
# Período Teste - 2004-12-15 00:00:00 / 2005-12-20 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00007
# R2 = 0.99177
# ==========================================================================================
# 11° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2005-12-20 00:00:00
# Amostra Treino - 2812
# Período Teste - 2005-12-21 00:00:00 / 2006-12-13 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00009
# R2 = 0.97525
# ==========================================================================================
# 12° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2006-12-13 00:00:00
# Amostra Treino - 3067
# Período Teste - 2006-12-14 00:00:00 / 2007-12-28 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00009
# R2 = 0.99468
# ==========================================================================================
# 13° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2007-12-28 00:00:00
# Amostra Treino - 3322
# Período Teste - 2008-01-02 00:00:00 / 2009-01-09 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00038
# R2 = 0.99393
# ==========================================================================================
# 14° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2009-01-09 00:00:00
# Amostra Treino - 3577
# Período Teste - 2009-01-12 00:00:00 / 2010-01-20 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00015
# R2 = 0.99624
# ==========================================================================================
# 15° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2010-01-20 00:00:00
# Amostra Treino - 3832
# Período Teste - 2010-01-21 00:00:00 / 2011-02-01 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00008
# R2 = 0.95620
# ==========================================================================================
# 16° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2011-02-01 00:00:00
# Amostra Treino - 4087
# Período Teste - 2011-02-02 00:00:00 / 2012-02-08 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00011
# R2 = 0.98341
# ==========================================================================================
# 17° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2012-02-08 00:00:00
# Amostra Treino - 4342
# Período Teste - 2012-02-09 00:00:00 / 2013-02-26 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00008
# R2 = 0.97982
# ==========================================================================================
# 18° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2013-02-26 00:00:00
# Amostra Treino - 4597
# Período Teste - 2013-02-27 00:00:00 / 2014-03-06 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00007
# R2 = 0.98196
# ==========================================================================================
# 19° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2014-03-06 00:00:00
# Amostra Treino - 4852
# Período Teste - 2014-03-07 00:00:00 / 2015-03-17 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00013
# R2 = 0.97292
# ==========================================================================================
# 20° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2015-03-17 00:00:00
# Amostra Treino - 5107
# Período Teste - 2015-03-18 00:00:00 / 2016-03-31 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00014
# R2 = 0.98644
# ==========================================================================================
# 21° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2016-03-31 00:00:00
# Amostra Treino - 5362
# Período Teste - 2016-04-01 00:00:00 / 2017-04-06 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00007
# R2 = 0.99242
# ==========================================================================================
# 22° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2017-04-06 00:00:00
# Amostra Treino - 5617
# Período Teste - 2017-04-07 00:00:00 / 2018-04-09 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00005
# R2 = 0.99517
# ==========================================================================================
# 23° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2018-04-09 00:00:00
# Amostra Treino - 5872
# Período Teste - 2018-04-10 00:00:00 / 2019-04-23 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00008
# R2 = 0.99076
# ==========================================================================================
# 24° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2019-04-23 00:00:00
# Amostra Treino - 6127
# Período Teste - 2019-04-24 00:00:00 / 2020-05-04 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00024
# R2 = 0.98830
# ==========================================================================================
# 25° iteração
# Perído Treino - 1995-02-27 00:00:00 / 2020-05-04 00:00:00
# Amostra Treino - 6382
# Período Teste - 2020-05-05 00:00:00 / 2021-05-14 00:00:00
# Amostra Teste - 255
# Erro Médio Quadrático = 0.00008
# R2 = 0.99379
# ==========================================================================================
# <AxesSubplot:>

# %% [markdown]
# ### Conclusões
#
# **Mesmas observações apresentadas para o Lasso**
#
# A validação cruzada mostra que a baixa é muito mais sensível às variações de previsão, apresentando os maiores erros médios e menores R2.
#
# Prever a baixa é mais difícil para o algoritmo, mesmo utilizando-se de uma validação cruzada
#
# Para o fechamento e a alta, a cruva apresentada foi a esperada, com o erro caindo e o r2 aumentando conforme avançava a validação cruzada
